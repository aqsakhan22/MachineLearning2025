# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'cgpa', 'iq', 'placement'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
df.placement.value_counts() # class imbalance means data may classes kitni hai
# Out:
# placement
# 1    50
# 0    50
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.iq)
# Out:
# pandas.core.series.Series

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
#permananet changes in a particular cell
# df.drop(columns=['Unnamed: 0'])

# %%
plt.title('Placement Data')
plt.xlabel('cgpa')
plt.ylabel('IQ Level')
plt.scatter(x=df['cgpa'],y=df['iq'])
# c is category
plt.show()

# %%
plt.title('Placement Data')
plt.xlabel('cgpa')
plt.ylabel('IQ Level')
plt.scatter(x=df['cgpa'],y=df['iq'],c=df['placement'])
plt.savefig('placementscatterplot')
# c is category
plt.show()

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]>

# %%
x=df.drop(columns=['placement'])
y=df['placement']

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
# train test split 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=40)

# %%
X_train
# Out:
#     cgpa     iq
# 72   7.3  116.0
# 66   6.9   96.0
# 69   8.5  120.0
# 67   5.0  118.0
# 26   7.0  199.0
# ..   ...    ...
# 56   6.1   65.0
# 37   8.1  149.0
# 7    5.0   63.0
# 91   7.5  158.0
# 70   6.3  127.0
#
# [80 rows x 2 columns]

# %%
len(X_test)
# Out:
# 20

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
pd.DataFrame({'y_test':y_test,'y_predict':y_pred})
# Out:
#     y_test  y_predict
# 79       1          1
# 75       0          0
# 63       1          1
# 15       0          0
# 38       1          1
# 11       1          1
# 40       0          0
# 45       1          0
# 39       0          0
# 62       0          0
# 86       0          0
# 4        0          0
# 47       0          0
# 27       1          1
# 81       0          0
# 17       0          0
# 82       1          1
# 33       0          1
# 9        0          0
# 92       0          0

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,f1_score,classification_report
# classificationn may accuracy score wo huta hai k kitna sahi bataya or kitna ghalat
# classification may like kitna percent sahi bataya or kitna ghalat
# total number of result / total no of t
# # correct classifications / total classification
# number of predicted / correct data

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
print('confusion matrix',confusion_matrix(y_test,y_pred))
# Out:
# confusion matrix [[12  1]
#  [ 1  6]]

# %%
print('classification report',classification_report(y_test,y_pred))
# Out:
# classification report               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        13
#            1       0.86      0.86      0.86         7
#
#     accuracy                           0.90        20
#    macro avg       0.89      0.89      0.89        20
# weighted avg       0.90      0.90      0.90        20

# %%
# precision like kitna sahi bataya usny only bt possitive ki hugi
# recal jo ghalti ki hai usko add kerna hai
